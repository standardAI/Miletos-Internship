# %%
# This mounts your Google Drive to the Colab VM.
#from google.colab import drive
#drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = '/home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
#import sys
#sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2/cs231n/datasets
# !bash get_datasets.sh
# %cd '/home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2'
# Out:
# /home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2/cs231n/datasets
# /home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from Assignment 1. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.   
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 7.696805129597462e-08
# W2 relative error: 1.7087519156186903e-05
# W3 relative error: 2.9508423550094495e-07
# b1 relative error: 4.660094650186831e-09
# b2 relative error: 2.085654124402131e-09
# b3 relative error: 6.598642296022133e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.904542008453064e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 2.1311298702113723e-08
# b1 relative error: 1.168319680050491e-08
# b2 relative error: 1.7223752732008252e-09
# b3 relative error: 1.3200479211447775e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 1e-1   # 1e-2 -> 1e-1
learning_rate = 1e-4  # 1e-4 -> 1e-2
model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# /home/cosmos/Documents/Miletos/CS231n/assignment2_colab/assignment2/cs231n/layers.py:146: RuntimeWarning: divide by zero encountered in log
#   loss = -np.log(np.exp(correct_class_scores)/denominators)  # (N, 1)
# (Iteration 1 / 40) loss: inf
# (Epoch 0 / 20) train acc: 0.020000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.040000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.108000
# (Epoch 3 / 20) train acc: 0.300000; val_acc: 0.144000
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.135000
# (Epoch 5 / 20) train acc: 0.420000; val_acc: 0.157000
# (Iteration 11 / 40) loss: 31.172835
# (Epoch 6 / 20) train acc: 0.540000; val_acc: 0.153000
# (Epoch 7 / 20) train acc: 0.560000; val_acc: 0.146000
# (Epoch 8 / 20) train acc: 0.640000; val_acc: 0.147000
# (Epoch 9 / 20) train acc: 0.680000; val_acc: 0.156000
# (Epoch 10 / 20) train acc: 0.740000; val_acc: 0.153000
# (Iteration 21 / 40) loss: 24.023362
# (Epoch 11 / 20) train acc: 0.780000; val_acc: 0.152000
# (Epoch 12 / 20) train acc: 0.820000; val_acc: 0.147000
# (Epoch 13 / 20) train acc: 0.920000; val_acc: 0.143000
# (Epoch 14 / 20) train acc: 0.920000; val_acc: 0.140000
# (Epoch 15 / 20) train acc: 0.960000; val_acc: 0.138000
# (Iteration 31 / 40) loss: 0.030175
# (Epoch 16 / 20) train acc: 0.980000; val_acc: 0.141000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.145000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.145000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.145000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.145000

# %%
dims = [100] * 4
hs = []
x = np.random.randn(16, dims[0])
for Din, Dout in zip(dims[:-1], dims[1:]):
    #W = np.random.randn(Din, Dout) / np.sqrt(Din)
    W = 0.01 * np.random.randn(Din, Dout)
    x = 1/(1 + np.exp(-(x.dot(W))))
    #x = np.tanh(x.dot(W))
    hs.append(x)

fig, axs = plt.subplots(1, 14, sharey=True, tight_layout=True, figsize=(20, 4))
for i, h in enumerate(hs):
    axs[i].hist(h.ravel(), bins=100, density=True)
    axs[i].set_title('std: %.4f' % h.std())

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 2e-3
weight_scale = 1e-1
#learning_rate = 2e-3
#weight_scale = 1e-5
model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 125.786833
# (Epoch 0 / 20) train acc: 0.280000; val_acc: 0.125000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.240000; val_acc: 0.128000
# (Epoch 3 / 20) train acc: 0.540000; val_acc: 0.122000
# (Epoch 4 / 20) train acc: 0.760000; val_acc: 0.133000
# (Epoch 5 / 20) train acc: 0.840000; val_acc: 0.111000
# (Iteration 11 / 40) loss: 2.521222
# (Epoch 6 / 20) train acc: 0.800000; val_acc: 0.117000
# (Epoch 7 / 20) train acc: 0.820000; val_acc: 0.133000
# (Epoch 8 / 20) train acc: 0.900000; val_acc: 0.125000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.132000
# (Epoch 10 / 20) train acc: 0.960000; val_acc: 0.125000
# (Iteration 21 / 40) loss: 0.035288
# (Epoch 11 / 20) train acc: 0.960000; val_acc: 0.123000
# (Epoch 12 / 20) train acc: 0.980000; val_acc: 0.123000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.121000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.127000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.129000
# (Iteration 31 / 40) loss: 0.002199
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.129000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.129000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.128000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.129000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.128000

# %%
dims = [100] * 6
hs = []
x = np.random.randn(16, dims[0])
for Din, Dout in zip(dims[:-1], dims[1:]):
    #W = np.random.randn(Din, Dout) / np.sqrt(Din)
    W = 0.1 * np.random.randn(Din, Dout)
    x = 1/(1 + np.exp(-(x.dot(W))))
    #x = np.tanh(x.dot(W))
    hs.append(x)

fig, axs = plt.subplots(1, 14, sharey=True, tight_layout=True, figsize=(20, 4))
for i, h in enumerate(hs):
    axs[i].hist(h.ravel(), bins=100, density=True)
    axs[i].set_title('std: %.4f' % h.std())

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
#
# 5 layered one. The effect of collection of valu

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")
    
for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 3.298658
# (Epoch 0 / 5) train acc: 0.128000; val_acc: 0.157000
# (Iteration 11 / 200) loss: 2.230440
# (Iteration 21 / 200) loss: 2.130139
# (Iteration 31 / 200) loss: 2.194044
# (Epoch 1 / 5) train acc: 0.239000; val_acc: 0.262000
# (Iteration 41 / 200) loss: 2.081010
# (Iteration 51 / 200) loss: 2.078427
# (Iteration 61 / 200) loss: 2.070926
# (Iteration 71 / 200) loss: 2.043408
# (Epoch 2 / 5) train acc: 0.310000; val_acc: 0.292000
# (Iteration 81 / 200) loss: 1.925819
# (Iteration 91 / 200) loss: 1.857075
# (Iteration 101 / 200) loss: 1.972316
# (Iteration 111 / 200) loss: 1.932838
# (Epoch 3 / 5) train acc: 0.292000; val_acc: 0.297000
# (Iteration 121 / 200) loss: 2.053606
# (Iteration 131 / 200) loss: 1.877331
# (Iteration 141 / 200) loss: 2.000763
# (Iteration 151 / 200) loss: 1.885562
# (Epoch 4 / 5) train acc: 0.356000; val_acc: 0.313000
# (Iteration 161 / 200) loss: 1.700173
# (Iteration 171 / 200) loss: 1.890368
# (Iteration 181 / 200) loss: 1.808571
# (Iteration 191 / 200) loss: 1.721472
# (Epoch 5 / 5) train acc: 0.368000; val_acc: 0.316000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.580591
# (Epoch 0 / 5) train acc: 0.117000; val_acc: 0.096000
# (Iteration 11 / 200) loss: 2.191262
# (Iteration 21 / 200) loss: 2.187440
# (Iteration 31 / 200) loss: 1.981652
# (Epoch 1 / 5) train acc: 0.345000; val_acc: 0.267000
# (Iteration 41 / 200) loss: 1.807696
# (Iteration 51 / 200) loss: 1.965316
# (Iteration 61 / 200) loss: 1.852113
# (Iteration 71 / 200) loss: 1.727649
# (Epoch 2 / 5) train acc: 0.407000; val_acc: 0.315000
# (Iteration 81 / 200) loss: 1.924846
# (Iteration 91 / 200) loss: 1.770390
# (Iteration 101 / 200) loss: 1.631587
# (Iteration 111 / 200) loss: 1.682724
# (Epoch 3 / 5) train acc: 0.488000; val_acc: 0.347000
# (Iteration 121 / 200) loss: 1.601658
# (Iteration 131 / 200) loss: 1.407349
# (Iteration 141 / 200) loss: 1.537576
# (Iteration 151 / 200) loss: 1.427957
# (Epoch 4 / 5) train acc: 0.503000; val_acc: 0.351000
# (Iteration 161 / 200) loss: 1.516955
# (Iteration 171 / 200) loss: 1.141725
# (Iteration 181 / 200) loss: 1.333416
# (Iteration 191 / 200) loss: 1.373061
# (Epoch 5 / 5) train acc: 0.552000; val_acc: 0.361000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()
    
fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")
    
for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 2.596672
# (Epoch 0 / 5) train acc: 0.137000; val_acc: 0.125000
# (Iteration 11 / 200) loss: 2.141510
# (Iteration 21 / 200) loss: 1.961921
# (Iteration 31 / 200) loss: 1.944319
# (Epoch 1 / 5) train acc: 0.346000; val_acc: 0.314000
# (Iteration 41 / 200) loss: 1.783162
# (Iteration 51 / 200) loss: 1.926098
# (Iteration 61 / 200) loss: 1.690384
# (Iteration 71 / 200) loss: 1.624596
# (Epoch 2 / 5) train acc: 0.429000; val_acc: 0.354000
# (Iteration 81 / 200) loss: 1.583101
# (Iteration 91 / 200) loss: 1.568257
# (Iteration 101 / 200) loss: 1.509310
# (Iteration 111 / 200) loss: 1.312592
# (Epoch 3 / 5) train acc: 0.524000; val_acc: 0.377000
# (Iteration 121 / 200) loss: 1.763631
# (Iteration 131 / 200) loss: 1.483104
# (Iteration 141 / 200) loss: 1.314758
# (Iteration 151 / 200) loss: 1.253134
# (Epoch 4 / 5) train acc: 0.537000; val_acc: 0.371000
# (Iteration 161 / 200) loss: 1.490993
# (Iteration 171 / 200) loss: 1.148028
# (Iteration 181 / 200) loss: 1.406656
# (Iteration 191 / 200) loss: 1.377673
# (Epoch 5 / 5) train acc: 0.627000; val_acc: 0.367000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.859327
# (Epoch 0 / 5) train acc: 0.134000; val_acc: 0.129000
# (Iteration 11 / 200) loss: 2.171066
# (Iteration 21 / 200) loss: 1.942864
# (Iteration 31 / 200) loss: 1.877374
# (Epoch 1 / 5) train acc: 0.354000; val_acc: 0.298000
# (Iteration 41 / 200) loss: 1.864812
# (Iteration 51 / 200) loss: 1.751777
# (Iteration 61 / 200) loss: 1.657955
# (Iteration 71 / 200) loss: 1.651883
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.338000
# (Iteration 81 / 200) loss: 1.680081
# (Iteration 91 / 200) loss: 1.699816
# (Iteration 101 / 200) loss: 1.552225
# (Iteration 111 / 200) loss: 1.551949
# (Epoch 3 / 5) train acc: 0.470000; val_acc: 0.338000
# (Iteration 121 / 200) loss: 1.526649
# (Iteration 131 / 200) loss: 1.552280
# (Iteration 141 / 200) loss: 1.414899
# (Iteration 151 / 200) loss: 1.376209
# (Epoch 4 / 5) train acc: 0.522000; val_acc: 0.343000
# (Iteration 161 / 200) loss: 1.442674
# (Iteration 171 / 200) loss: 1.338708
# (Iteration 181 / 200) loss: 1.501093
# (Iteration 191 / 200) loss: 1.463944
# (Epoch 5 / 5) train acc: 0.537000; val_acc: 0.364000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# Divides large numbers with large values small numbers with small values. cache grows continually, so step size gets smaller.
# No, because Adam has RMSProp's smoothed cache update.

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
best_acc = 0

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

#learning_rates = [1e-4, 1e-3, 1e-2]
learning_rates = {'rmsprop': 1e-3, 'adam': 1e-2}

hidden_sizes = [[100]*3, [100]*4, [100]*5]
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    for hidden_size in hidden_sizes:
        model = FullyConnectedNet(
                hidden_size,
                weight_scale=5e-2
                )
        solver = Solver(
            model,
            small_data,
            num_epochs=5,
            batch_size=100,
            update_rule=update_rule,
            optim_config={'learning_rate': learning_rates[update_rule]},
            verbose=True
        )
        
        solver.train()
        print('optim: %s, lr: %e, hidden_size: %d, train accuracy: %f, val accuracy: %f' % 
        (update_rule, learning_rates[update_rule], len(hidden_size), solver.train_acc_history[-1], solver.val_acc_history[-1]))

        if solver.val_acc_history[-1] > best_acc:
            best_acc = solver.val_acc_history[-1]
            best_model = model


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 13.079586
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.105000
# (Iteration 11 / 200) loss: 3.954896
# (Iteration 21 / 200) loss: 2.301533
# (Iteration 31 / 200) loss: 2.300741
# (Epoch 1 / 5) train acc: 0.115000; val_acc: 0.113000
# (Iteration 41 / 200) loss: 2.304793
# (Iteration 51 / 200) loss: 2.300564
# (Iteration 61 / 200) loss: 2.303210
# (Iteration 71 / 200) loss: 2.303570
# (Epoch 2 / 5) train acc: 0.096000; val_acc: 0.078000
# (Iteration 81 / 200) loss: 2.303984
# (Iteration 91 / 200) loss: 2.306494
# (Iteration 101 / 200) loss: 2.299445
# (Iteration 111 / 200) loss: 2.302497
# (Epoch 3 / 5) train acc: 0.102000; val_acc: 0.078000
# (Iteration 121 / 200) loss: 2.310722
# (Iteration 131 / 200) loss: 2.300210
# (Iteration 141 / 200) loss: 2.308391
# (Iteration 151 / 200) loss: 2.292851
# (Epoch 4 / 5) train acc: 0.112000; val_acc: 0.078000
# (Iteration 161 / 200) loss: 2.304253
# (Iteration 171 / 200) loss: 2.298520
# (Iteration 181 / 200) loss: 2.305121
# (Iteration 191 / 200) loss: 2.308495
# (Epoch 5 / 5) train acc: 0.118000; val_acc: 0.078000
# optim: adam, lr: 1.000000e-02, hidden_size: 3, train accuracy: 0.118000, val accuracy: 0.078000
# (Iteration 1 / 200) loss: 4.488167
# (Epoch 0 / 5) train acc: 0.097000; val_acc: 0.090000
# (Iteration 11 / 200) loss: 2.839365
# (Iteration 21 / 200) loss: 2.290399
# (Iteration 31 / 200) loss: 2.167718
# (Epoch 1 / 5) train acc: 0.204000; val_acc: 0.183000
# (Iteration 41 / 200) loss: 2.110423
# (Iteration 51 / 200) loss: 2.080538
# (Iteration 61 / 200) loss: 2.179682
# (Iteration 71 / 200) loss: 1.894153
# (Epoch 2 / 5) train acc: 0.232000; val_acc: 0.213000
# (Iteration 81 / 200) loss: 1.919247
# (Iteration 91 / 200) loss: 2.017033
# (Iteration 101 / 200) loss: 2.104479
# (Iteration 111 / 200) loss: 1.968647
# (Epoch 3 / 5) train acc: 0.254000; val_acc: 0.253000
# (Iteration 121 / 200) loss: 1.969676
# (Iteration 131 / 200) loss: 1.859869
# (Iteration 141 / 200) loss: 1.918124
# (Iteration 151 / 200) loss: 1.942941
# (Epoch 4 / 5) train acc: 0.336000; val_acc: 0.296000
# (Iteration 161 / 200) loss: 2.069152
# (Iteration 171 / 200) loss: 1.950098
# (Iteration 181 / 200) loss: 1.800153
# (Iteration 191 / 200) loss: 1.909542
# (Epoch 5 / 5) train acc: 0.288000; val_acc: 0.269000
# optim: adam, lr: 1.000000e-02, hidden_size: 4, train accuracy: 0.288000, val accuracy: 0.269000
# (Iteration 1 / 200) loss: 2.913672
# (Epoch 0 / 5) train acc: 0.113000; val_acc: 0.113000
# (Iteration 11 / 200) loss: 2.214396
# (Iteration 21 / 200) loss: 2.126056
# (Iteration 31 / 200) loss: 2.136440
# (Epoch 1 / 5) train acc: 0.184000; val_acc: 0.187000
# (Iteration 41 / 200) loss: 2.160923
# (Iteration 51 / 200) loss: 2.128866
# (Iteration 61 / 200) loss: 2.083601
# (Iteration 71 / 200) loss: 2.223920
# (Epoch 2 / 5) train acc: 0.209000; val_acc: 0.184000
# (Iteration 81 / 200) loss: 1.947361
# (Iteration 91 / 200) loss: 2.130907
# (Iteration 101 / 200) loss: 1.951487
# (Iteration 111 / 200) loss: 2.129354
# (Epoch 3 / 5) train acc: 0.197000; val_acc: 0.193000
# (Iteration 121 / 200) loss: 1.863919
# (Iteration 131 / 200) loss: 1.954173
# (Iteration 141 / 200) loss: 1.963041
# (Iteration 151 / 200) loss: 2.073973
# (Epoch 4 / 5) train acc: 0.200000; val_acc: 0.172000
# (Iteration 161 / 200) loss: 1.993809
# (Iteration 171 / 200) loss: 1.960095
# (Iteration 181 / 200) loss: 2.034971
# (Iteration 191 / 200) loss: 2.069204
# (Epoch 5 / 5) train acc: 0.236000; val_acc: 0.238000
# optim: adam, lr: 1.000000e-02, hidden_size: 5, train accuracy: 0.236000, val accuracy: 0.238000
# Running with  rmsprop
# (Iteration 1 / 200) loss: 10.676985
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.081000
# (Iteration 11 / 200) loss: 3.446829
# (Iteration 21 / 200) loss: 2.475834
# (Iteration 31 / 200) loss: 2.010037
# (Epoch 1 / 5) train acc: 0.330000; val_acc: 0.246000
# (Iteration 41 / 200) loss: 2.036180
# (Iteration 51 / 200) loss: 1.963355
# (Iteration 61 / 200) loss: 1.803588
# (Iteration 71 / 200) loss: 1.604571
# (Epoch 2 / 5) train acc: 0.410000; val_acc: 0.295000
# (Iteration 81 / 200) loss: 1.595355
# (Iteration 91 / 200) loss: 1.507005
# (Iteration 101 / 200) loss: 1.905453
# (Iteration 111 / 200) loss: 1.541471
# (Epoch 3 / 5) train acc: 0.484000; val_acc: 0.324000
# (Iteration 121 / 200) loss: 1.828831
# (Iteration 131 / 200) loss: 1.613158
# (Iteration 141 / 200) loss: 1.820255
# (Iteration 151 / 200) loss: 1.584035
# (Epoch 4 / 5) train acc: 0.491000; val_acc: 0.335000
# (Iteration 161 / 200) loss: 1.524598
# (Iteration 171 / 200) loss: 1.700261
# (Iteration 181 / 200) loss: 1.371784
# (Iteration 191 / 200) loss: 1.307973
# (Epoch 5 / 5) train acc: 0.513000; val_acc: 0.308000
# optim: rmsprop, lr: 1.000000e-03, hidden_size: 3, train accuracy: 0.513000, val accuracy: 0.308000
# (Iteration 1 / 200) loss: 3.393246
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.103000
# (Iteration 11 / 200) loss: 2.245630
# (Iteration 21 / 200) loss: 2.247568
# (Iteration 31 / 200) loss: 2.005292
# (Epoch 1 / 5) train acc: 0.351000; val_acc: 0.297000
# (Iteration 41 / 200) loss: 1.814094
# (Iteration 51 / 200) loss: 1.674923
# (Iteration 61 / 200) loss: 2.000399
# (Iteration 71 / 200) loss: 1.834314
# (Epoch 2 / 5) train acc: 0.355000; val_acc: 0.288000
# (Iteration 81 / 200) loss: 1.908772
# (Iteration 91 / 200) loss: 1.826090
# (Iteration 101 / 200) loss: 1.579623
# (Iteration 111 / 200) loss: 1.600318
# (Epoch 3 / 5) train acc: 0.428000; val_acc: 0.318000
# (Iteration 121 / 200) loss: 1.706332
# (Iteration 131 / 200) loss: 1.363141
# (Iteration 141 / 200) loss: 1.571223
# (Iteration 151 / 200) loss: 1.463409
# (Epoch 4 / 5) train acc: 0.469000; val_acc: 0.315000
# (Iteration 161 / 200) loss: 1.440958
# (Iteration 171 / 200) loss: 1.498956
# (Iteration 181 / 200) loss: 1.394000
# (Iteration 191 / 200) loss: 1.345026
# (Epoch 5 / 5) train acc: 0.524000; val_acc: 0.319000
# optim: rmsprop, lr: 1.000000e-03, hidden_size: 4, train accuracy: 0.524000, val accuracy: 0.319000
# (Iteration 1 / 200) loss: 2.397232
# (Epoch 0 / 5) train acc: 0.114000; val_acc: 0.142000
# (Iteration 11 / 200) loss: 2.282440
# (Iteration 21 / 200) loss: 2.043780
# (Iteration 31 / 200) loss: 1.850026
# (Epoch 1 / 5) train acc: 0.325000; val_acc: 0.301000
# (Iteration 41 / 200) loss: 1.893679
# (Iteration 51 / 200) loss: 1.903611
# (Iteration 61 / 200) loss: 1.983878
# (Iteration 71 / 200) loss: 1.547268
# (Epoch 2 / 5) train acc: 0.349000; val_acc: 0.292000
# (Iteration 81 / 200) loss: 1.885470
# (Iteration 91 / 200) loss: 1.733740
# (Iteration 101 / 200) loss: 1.618848
# (Iteration 111 / 200) loss: 1.375009
# (Epoch 3 / 5) train acc: 0.456000; val_acc: 0.336000
# (Iteration 121 / 200) loss: 1.538608
# (Iteration 131 / 200) loss: 1.461423
# (Iteration 141 / 200) loss: 1.671352
# (Iteration 151 / 200) loss: 1.576503
# (Epoch 4 / 5) train acc: 0.505000; val_acc: 0.364000
# (Iteration 161 / 200) loss: 1.478887
# (Iteration 171 / 200) loss: 1.479564
# (Iteration 181 / 200) loss: 1.443267
# (Iteration 191 / 200) loss: 1.243346
# (Epoch 5 / 5) train acc: 0.540000; val_acc: 0.381000
# optim: rmsprop, lr: 1.000000e-03, hidden_size: 5, train accuracy: 0.540000, val accuracy: 0.381000

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.381
# Test set accuracy:  0.342
